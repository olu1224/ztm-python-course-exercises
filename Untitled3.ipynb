# %% [markdown]
# <a href="https://colab.research.google.com/github/olu1224/ztm-python-course-exercises/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
a,b,c,d = 10,12,0,-1

# %%
print(str(c) in str(a))
# Out:
# True
